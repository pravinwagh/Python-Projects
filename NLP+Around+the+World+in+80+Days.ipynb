# %%
# Import Libaries
import string
from nltk.corpus import stopwords
import pandas as pd
import re
from collections import Counter

# %%
# View the stopwords
stopwords.words('english')[0:10]
# Out:
# [u'i',
#  u'me',
#  u'my',
#  u'myself',
#  u'we',
#  u'our',
#  u'ours',
#  u'ourselves',
#  u'you',
#  u'your']

# %%
# Load the book "Around the world in 80 days"
ReadBook = open('C:\Users\pravinw\Documents\Fractal\DATA SCIENTIST\PractiseAssignment_Simplilearn\Around the world in 80 days.txt',"r")

# %%
# Read the book line wise and remove the line breaks
Book_Lines = ReadBook.read().replace('\n',' ')

# %%
# Now we remove the punctuations
no_punctuation = [char for char in Book_Lines if char not in string.punctuation]
no_punctuation
# Out:
# ['T',
#  'h',
#  'e',
#  ' ',
#  'P',
#  'r',
#  'o',
#  'j',
#  'e',
#  'c',
#  't',
#  ' ',
#  'G',
#  'u',
#  't',
#  'e',
#  'n',
#  'b',
#  'e',
#  'r',
#  'g',
#  ' ',
#  'E',
#  'B',
#  'o',
#  'o',
#  'k',
#  ' ',
#  'o',
#  'f',
#  ' ',
#  'A',
#  'r',
#  'o',
#  'u',
#  'n',
#  'd',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  'W',
#  'o',
#  'r',
#  'l',
#  'd',
#  ' ',
#  'i',
#  'n',
#  ' ',
#  '8',
#  '0',
#  ' ',
#  'D',
#  'a',
#  'y',
#  's',
#  ' ',
#  'b',
#  'y',
#  ' ',
#  'J',
#  'u',
#  'l',
#  'e',
#  's',
#  ' ',
#  'V',
#  'e',
#  'r',
#  'n',
#  'e',
#  ' ',
#  ' ',
#  'T',
#  'h',
#  'i',
#  's',
#  ' ',
#  'e',
#  'B',
#  'o',
#  'o',
#  'k',
#  ' ',
#  'i',
#  's',
#  ' ',
#  'f',
#  'o',
#  'r',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  'u',
#  's',
#  'e',
#  ' ',
#  'o',
#  'f',
#  ' ',
#  'a',
#  'n',
#  'y',
#  'o',
#  'n',
#  'e',
#  ' ',
#  'a',
#  'n',
#  'y',
#  'w',
#  'h',
#  'e',
#  'r',
#  'e',
#  ' ',
#  'a',
#  't',
#  ' ',
#  'n',
#  'o',
#  ' ',
#  'c',
#  'o',
#  's',
#  't',
#  ' ',
#  'a',
#  'n',
#  'd',
#  ' ',
#  'w',
#  'i',
#  't',
#  'h',
#  ' ',
#  'a',
#  'l',
#  'm',
#  'o',
#  's',
#  't',
#  ' ',
#  'n',
#  'o',
#  ' ',
#  'r',
#  'e',
#  's',
#  't',
#  'r',
#  'i',
#  'c',
#  't',
#  'i',
#  'o',
#  'n',
#  's',
#  ' ',
#  'w',
#  'h',
#  'a',
#  't',
#  's',
#  'o',
#  'e',
#  'v',
#  'e',
#  'r',
#  ' ',
#  ' ',
#  'Y',
#  'o',
#  'u',
#  ' ',
#  'm',
#  'a',
#  'y',
#  ' ',
#  'c',
#  'o',
#  'p',
#  'y',
#  ' ',
#  'i',
#  't',
#  ' ',
#  'g',
#  'i',
#  'v',
#  'e',
#  ' ',
#  'i',
#  't',
#  ' ',
#  'a',
#  'w',
#  'a',
#  'y',
#  ' ',
#  'o',
#  'r',
#  ' ',
#  'r',
#  'e',
#  'u',
#  's',
#  'e',
#  ' ',
#  'i',
#  't',
#  ' ',
#  'u',
#  'n',
#  'd',
#  'e',
#  'r',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  't',
#  'e',
#  'r',
#  'm',
#  's',
#  ' ',
#  'o',
#  'f',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  'P',
#  'r',
#  'o',
#  'j',
#  'e',
#  'c',
#  't',
#  ' ',
#  'G',
#  'u',
#  't',
#  'e',
#  'n',
#  'b',
#  'e',
#  'r',
#  'g',
#  ' ',
#  'L',
#  'i',
#  'c',
#  'e',
#  'n',
#  's',
#  'e',
#  ' ',
#  'i',
#  'n',
#  'c',
#  'l',
#  'u',
#  'd',
#  'e',
#  'd',
#  ' ',
#  'w',
#  'i',
#  't',
#  'h',
#  ' ',
#  't',
#  'h',
#  'i',
#  's',
#  ' ',
#  'e',
#  'B',
#  'o',
#  'o',
#  'k',
#  ' ',
#  'o',
#  'r',
#  ' ',
#  'o',
#  'n',
#  'l',
#  'i',
#  'n',
#  'e',
#  ' ',
#  'a',
#  't',
#  ' ',
#  'w',
#  'w',
#  'w',
#  'g',
#  'u',
#  't',
#  'e',
#  'n',
#  'b',
#  'e',
#  'r',
#  'g',
#  'n',
#  'e',
#  't',
#  ' ',
#  ' ',
#  ' ',
#  'T',
#  'i',
#  't',
#  'l',
#  'e',
#  ' ',
#  'A',
#  'r',
#  'o',
#  'u',
#  'n',
#  'd',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  'W',
#  'o',
#  'r',
#  'l',
#  'd',
#  ' ',
#  'i',
#  'n',
#  ' ',
#  '8',
#  '0',
#  ' ',
#  'D',
#  'a',
#  'y',
#  's',
#  ' ',
#  ' ',
#  'A',
#  'u',
#  't',
#  'h',
#  'o',
#  'r',
#  ' ',
#  'J',
#  'u',
#  'l',
#  'e',
#  's',
#  ' ',
#  'V',
#  'e',
#  'r',
#  'n',
#  'e',
#  ' ',
#  ' ',
#  'R',
#  'e',
#  'l',
#  'e',
#  'a',
#  's',
#  'e',
#  ' ',
#  'D',
#  'a',
#  't',
#  'e',
#  ' ',
#  'M',
#  'a',
#  'y',
#  ' ',
#  '1',
#  '5',
#  ' ',
#  '2',
#  '0',
#  '0',
#  '8',
#  ' ',
#  'E',
#  'B',
#  'o',
#  'o',
#  'k',
#  ' ',
#  '1',
#  '0',
#  '3',
#  ' ',
#  'L',
#  'a',
#  's',
#  't',
#  ' ',
#  'u',
#  'p',
#  'd',
#  'a',
#  't',
#  'e',
#  'd',
#  ' ',
#  'F',
#  'e',
#  'b',
#  'r',
#  'u',
#  'a',
#  'r',
#  'y',
#  ' ',
#  '1',
#  '8',
#  ' ',
#  '2',
#  '0',
#  '1',
#  '2',
#  ' ',
#  'L',
#  'a',
#  's',
#  't',
#  ' ',
#  'u',
#  'p',
#  'd',
#  'a',
#  't',
#  'e',
#  'd',
#  ' ',
#  'M',
#  'a',
#  'y',
#  ' ',
#  '5',
#  ' ',
#  '2',
#  '0',
#  '1',
#  '2',
#  ' ',
#  ' ',
#  'L',
#  'a',
#  'n',
#  'g',
#  'u',
#  'a',
#  'g',
#  'e',
#  ' ',
#  'E',
#  'n',
#  'g',
#  'l',
#  'i',
#  's',
#  'h',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'S',
#  'T',
#  'A',
#  'R',
#  'T',
#  ' ',
#  'O',
#  'F',
#  ' ',
#  'T',
#  'H',
#  'I',
#  'S',
#  ' ',
#  'P',
#  'R',
#  'O',
#  'J',
#  'E',
#  'C',
#  'T',
#  ' ',
#  'G',
#  'U',
#  'T',
#  'E',
#  'N',
#  'B',
#  'E',
#  'R',
#  'G',
#  ' ',
#  'E',
#  'B',
#  'O',
#  'O',
#  'K',
#  ' ',
#  'A',
#  'R',
#  'O',
#  'U',
#  'N',
#  'D',
#  ' ',
#  'T',
#  'H',
#  'E',
#  ' ',
#  'W',
#  'O',
#  'R',
#  'L',
#  'D',
#  ' ',
#  'I',
#  'N',
#  ' ',
#  '8',
#  '0',
#  ' ',
#  'D',
#  'A',
#  'Y',
#  'S',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'A',
#  'R',
#  'O',
#  'U',
#  'N',
#  'D',
#  ' ',
#  'T',
#  'H',
#  'E',
#  ' ',
#  'W',
#  'O',
#  'R',
#  'L',
#  'D',
#  ' ',
#  'I',
#  'N',
#  ' ',
#  'E',
#  'I',
#  'G',
#  'H',
#  'T',
#  'Y',
#  ' ',
#  'D',
#  'A',
#  'Y',
#  'S',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'C',
#  'O',
#  'N',
#  'T',
#  'E',
#  'N',
#  'T',
#  'S',
#  ' ',
#  ' ',
#  ' ',
#  'C',
#  'H',
#  'A',
#  'P',
#  'T',
#  'E',
#  'R',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'I',
#  ' ',
#  ' ',
#  'I',
#  'N',
#  ' ',
#  'W',
#  'H',
#  'I',
#  'C',
#  'H',
#  ' ',
#  'P',
#  'H',
#  'I',
#  'L',
#  'E',
#  'A',
#  'S',
#  ' ',
#  'F',
#  'O',
#  'G',
#  'G',
#  ' ',
#  'A',
#  'N',
#  'D',
#  ' ',
#  'P',
#  'A',
#  'S',
#  'S',
#  'E',
#  'P',
#  'A',
#  'R',
#  'T',
#  'O',
#  'U',
#  'T',
#  ' ',
#  'A',
#  'C',
#  'C',
#  'E',
#  'P',
#  'T',
#  ' ',
#  'E',
#  'A',
#  'C',
#  'H',
#  ' ',
#  'O',
#  'T',
#  'H',
#  'E',
#  'R',
#  ' ',
#  'T',
#  'H',
#  'E',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'O',
#  'N',
#  'E',
#  ' ',
#  'A',
#  'S',
#  ' ',
#  'M',
#  'A',
#  'S',
#  'T',
#  'E',
#  'R',
#  ' ',
#  'T',
#  'H',
#  'E',
#  ' ',
#  'O',
#  'T',
#  'H',
#  'E',
#  'R',
#  ' ',
#  'A',
#  'S',
#  ' ',
#  'M',
#  'A',
#  'N',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'I',
#  'I',
#  ' ',
#  ' ',
#  'I',
#  'N',
#  ' ',
#  'W',
#  'H',
#  'I',
#  'C',
#  'H',
#  ' ',
#  'P',
#  'A',
#  'S',
#  'S',
#  'E',
#  'P',
#  'A',
#  'R',
#  'T',
#  'O',
#  'U',
#  'T',
#  ' ',
#  'I',
#  'S',
#  ' ',
#  'C',
#  'O',
#  'N',
#  'V',
#  'I',
#  'N',
#  'C',
#  'E',
#  'D',
#  ' ',
#  'T',
#  'H',
#  'A',
#  'T',
#  ' ',
#  'H',
#  'E',
#  ' ',
#  'H',
#  'A',
#  'S',
#  ' ',
#  'A',
#  'T',
#  ' ',
#  'L',
#  'A',
#  'S',
#  'T',
#  ' ',
#  'F',
#  'O',
#  'U',
#  'N',
#  'D',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'H',
#  'I',
#  'S',
#  ' ',
#  'I',
#  'D',
#  'E',
#  'A',
#  'L',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'I',
#  'I',
#  'I',
#  ' ',
#  ' ',
#  'I',
#  'N',
#  ' ',
#  'W',
#  'H',
#  'I',
#  'C',
#  'H',
#  ' ',
#  'A',
#  ' ',
#  'C',
#  'O',
#  'N',
#  'V',
#  'E',
#  'R',
#  'S',
#  'A',
#  'T',
#  'I',
#  'O',
#  'N',
#  ' ',
#  'T',
#  'A',
#  'K',
#  'E',
#  'S',
#  ' ',
#  'P',
#  'L',
#  'A',
#  'C',
#  'E',
#  ' ',
#  'W',
#  'H',
#  'I',
#  'C',
#  'H',
#  ' ',
#  'S',
#  'E',
#  'E',
#  'M',
#  'S',
#  ' ',
#  'L',
#  'I',
#  'K',
#  'E',
#  'L',
#  'Y',
#  ' ',
#  'T',
#  'O',
#  ' ',
#  'C',
#  'O',
#  'S',
#  'T',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'P',
#  'H',
#  'I',
#  'L',
#  'E',
#  'A',
#  'S',
#  ' ',
#  'F',
#  'O',
#  'G',
#  'G',
#  ' ',
#  'D',
#  'E',
#  'A',
#  'R',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'I',
#  'V',
#  ' ',
#  ' ',
#  'I',
#  'N',
#  ' ',
#  'W',
#  'H',
#  'I',
#  'C',
#  'H',
#  ' ',
#  'P',
#  'H',
#  'I',
#  'L',
#  'E',
#  'A',
#  'S',
#  ' ',
#  'F',
#  'O',
#  'G',
#  'G',
#  ' ',
#  'A',
#  'S',
#  'T',
#  'O',
#  'U',
#  'N',
#  'D',
#  'S',
#  ' ',
#  'P',
#  'A',
#  'S',
#  'S',
#  'E',
#  'P',
#  'A',
#  'R',
#  'T',
#  'O',
#  'U',
#  'T',
#  ' ',
#  'H',
#  'I',
#  'S',
#  ' ',
#  'S',
#  'E',
#  'R',
#  'V',
#  'A',
#  'N',
#  'T',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'V',
#  ' ',
#  ' ',
#  'I',
#  'N',
#  ' ',
#  ...]

# %%
# Now we compile the book back without punctuations and line breaks
no_punctuation = ''.join(no_punctuation)
no_punctuation
# Out:
# 'The Project Gutenberg EBook of Around the World in 80 Days by Jules Verne  This eBook is for the use of anyone anywhere at no cost and with almost no restrictions whatsoever  You may copy it give it away or reuse it under the terms of the Project Gutenberg License included with this eBook or online at wwwgutenbergnet   Title Around the World in 80 Days  Author Jules Verne  Release Date May 15 2008 EBook 103 Last updated February 18 2012 Last updated May 5 2012  Language English    START OF THIS PROJECT GUTENBERG EBOOK AROUND THE WORLD IN 80 DAYS               AROUND THE WORLD IN EIGHTY DAYS    CONTENTS   CHAPTER        I  IN WHICH PHILEAS FOGG AND PASSEPARTOUT ACCEPT EACH OTHER THE          ONE AS MASTER THE OTHER AS MAN       II  IN WHICH PASSEPARTOUT IS CONVINCED THAT HE HAS AT LAST FOUND          HIS IDEAL      III  IN WHICH A CONVERSATION TAKES PLACE WHICH SEEMS LIKELY TO COST          PHILEAS FOGG DEAR       IV  IN WHICH PHILEAS FOGG ASTOUNDS PASSEPARTOUT HIS SERVANT        V  IN WHICH A NEW SPECIES OF FUNDS UNKNOWN TO THE MONEYED MEN          APPEARS ON CHANGE       VI  IN WHICH FIX THE DETECTIVE BETRAYS A VERY NATURAL IMPATIENCE      VII  WHICH ONCE MORE DEMONSTRATES THE USELESSNESS OF PASSPORTS AS          AIDS TO dETECTIVES     VIII  IN WHICH PASSEPARTOUT TALKS RATHER MORE PERHAPS THAN IS PRUDENT       IX  IN WHICH THE RED SEA AND THE INDIAN OCEAN PROVE PROPITIOUS          TO THE DESIGNS OF PHILEAS FOGG        X  IN WHICH PASSEPARTOUT IS ONLY TOO GLAD TO GET OFF WITH THE LOSS          OF HIS SHOES       XI  IN WHICH PHILEAS FOGG SECURES A CURIOUS MEANS OF CONVEYANCE          AT A FABULOUS PRICE      XII  IN WHICH PHILEAS FOGG AND HIS COMPANIONS VENTURE ACROSS THE          INDIAN FORESTS AND WHAT ENSUED     XIII  IN WHICH PASSEPARTOUT RECEIVES A NEW PROOF THAT FORTUNE FAVORS          THE BRAVE      XIV  IN WHICH PHILEAS FOGG DESCENDS THE WHOLE LENGTH OF THE BEAUTIFUL          VALLEY OF THE GANGES WITHOUT EVER THINKING OF SEEING IT       XV  IN WHICH THE BAG OF BANKNOTES DISGORGES SOME THOUSANDS OF POUNDS          MORE      XVI  IN WHICH FIX DOES NOT SEEM TO UNDERSTAND IN THE LEAST WHAT IS          SAID TO HIM     XVII  SHOWING WHAT HAPPENED ON THE VOYAGE FROM SINGAPORE TO HONG KONG    XVIII  IN WHICH PHILEAS FOGG PASSEPARTOUT AND FIX GO EACH ABOUT HIS          BUSINESS      XIX  IN WHICH PASSEPARTOUT TAKES A TOO GREAT INTEREST IN HIS MASTER          AND WHAT COMES OF IT       XX  IN WHICH FIX COMES FACE TO FACE WITH PHILEAS FOGG      XXI  IN WHICH THE MASTER OF THE TANKADERE RUNS GREAT RISK OF LOSING          A REWARD OF TWO HUNDRED POUNDS     XXII  IN WHICH PASSEPARTOUT FINDS OUT THAT EVEN AT THE ANTIPODES          IT IS CONVENIENT TO HAVE SOME MONEY IN ONES POCKET    XXIII  IN WHICH PASSEPARTOUTS NOSE BECOMES OUTRAGEOUSLY LONG    XXIV  DURING WHICH MR FOGG AND PARTY CROSS THE PACIFIC OCEAN      XXV  IN WHICH A SLIGHT GLIMPSE IS HAD OF SAN FRANCISCO     XXVI  IN WHICH PHILEAS FOGG AND PARTY TRAVEL BY THE PACIFIC RAILROAD    XXVII  IN WHICH PASSEPARTOUT UNDERGOES AT A SPEED OF TWENTY MILES AN          HOUR A COURSE OF MORMON HISTORY   XXVIII  IN WHICH PASSEPARTOUT DOES NOT SUCCEED IN MAKING ANYBODY LISTEN          TO REASON     XXIX  IN WHICH CERTAIN INCIDENTS ARE NARRATED WHICH ARE ONLY TO BE MET          WITH ON AMERICAN RAILROADS      XXX  IN WHICH PHILEAS FOGG SIMPLY DOES HIS DUTY     XXXI  IN WHICH FIX THE DETECTIVE CONSIDERABLY FURTHERS THE INTERESTS          OF PHILEAS FOGG    XXXII  IN WHICH PHILEAS FOGG ENGAGES IN A DIRECT STRUGGLE WITH BAD          FORTUNE   XXXIII  IN WHICH PHILEAS FOGG SHOWS HIMSELF EQUAL TO THE OCCASION    XXXIV  IN WHICH PHILEAS FOGG AT LAST REACHES LONDON     XXXV  IN WHICH PHILEAS FOGG DOES NOT HAVE TO REPEAT HIS ORDERS TO          PASSEPARTOUT TWICE    XXXVI  IN WHICH PHILEAS FOGGS NAME IS ONCE MORE AT A PREMIUM ON CHANGE   XXXVII  IN WHICH IT IS SHOWN THAT PHILEAS FOGG GAINED NOTHING BY HIS TOUR          AROUND THE WORLD UNLESS IT WERE HAPPINESS     Chapter I  IN WHICH PHILEAS FOGG A ...

# %%
# Here each word is splitted
no_punctuation.split()
# Out:
# ['The',
#  'Project',
#  'Gutenberg',
#  'EBook',
#  'of',
#  'Around',
#  'the',
#  'World',
#  'in',
#  '80',
#  'Days',
#  'by',
#  'Jules',
#  'Verne',
#  'This',
#  'eBook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'at',
#  'no',
#  'cost',
#  'and',
#  'with',
#  'almost',
#  'no',
#  'restrictions',
#  'whatsoever',
#  'You',
#  'may',
#  'copy',
#  'it',
#  'give',
#  'it',
#  'away',
#  'or',
#  'reuse',
#  'it',
#  'under',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'Project',
#  'Gutenberg',
#  'License',
#  'included',
#  'with',
#  'this',
#  'eBook',
#  'or',
#  'online',
#  'at',
#  'wwwgutenbergnet',
#  'Title',
#  'Around',
#  'the',
#  'World',
#  'in',
#  '80',
#  'Days',
#  'Author',
#  'Jules',
#  'Verne',
#  'Release',
#  'Date',
#  'May',
#  '15',
#  '2008',
#  'EBook',
#  '103',
#  'Last',
#  'updated',
#  'February',
#  '18',
#  '2012',
#  'Last',
#  'updated',
#  'May',
#  '5',
#  '2012',
#  'Language',
#  'English',
#  'START',
#  'OF',
#  'THIS',
#  'PROJECT',
#  'GUTENBERG',
#  'EBOOK',
#  'AROUND',
#  'THE',
#  'WORLD',
#  'IN',
#  '80',
#  'DAYS',
#  'AROUND',
#  'THE',
#  'WORLD',
#  'IN',
#  'EIGHTY',
#  'DAYS',
#  'CONTENTS',
#  'CHAPTER',
#  'I',
#  'IN',
#  'WHICH',
#  'PHILEAS',
#  'FOGG',
#  'AND',
#  'PASSEPARTOUT',
#  'ACCEPT',
#  'EACH',
#  'OTHER',
#  'THE',
#  'ONE',
#  'AS',
#  'MASTER',
#  'THE',
#  'OTHER',
#  'AS',
#  'MAN',
#  'II',
#  'IN',
#  'WHICH',
#  'PASSEPARTOUT',
#  'IS',
#  'CONVINCED',
#  'THAT',
#  'HE',
#  'HAS',
#  'AT',
#  'LAST',
#  'FOUND',
#  'HIS',
#  'IDEAL',
#  'III',
#  'IN',
#  'WHICH',
#  'A',
#  'CONVERSATION',
#  'TAKES',
#  'PLACE',
#  'WHICH',
#  'SEEMS',
#  'LIKELY',
#  'TO',
#  'COST',
#  'PHILEAS',
#  'FOGG',
#  'DEAR',
#  'IV',
#  'IN',
#  'WHICH',
#  'PHILEAS',
#  'FOGG',
#  'ASTOUNDS',
#  'PASSEPARTOUT',
#  'HIS',
#  'SERVANT',
#  'V',
#  'IN',
#  'WHICH',
#  'A',
#  'NEW',
#  'SPECIES',
#  'OF',
#  'FUNDS',
#  'UNKNOWN',
#  'TO',
#  'THE',
#  'MONEYED',
#  'MEN',
#  'APPEARS',
#  'ON',
#  'CHANGE',
#  'VI',
#  'IN',
#  'WHICH',
#  'FIX',
#  'THE',
#  'DETECTIVE',
#  'BETRAYS',
#  'A',
#  'VERY',
#  'NATURAL',
#  'IMPATIENCE',
#  'VII',
#  'WHICH',
#  'ONCE',
#  'MORE',
#  'DEMONSTRATES',
#  'THE',
#  'USELESSNESS',
#  'OF',
#  'PASSPORTS',
#  'AS',
#  'AIDS',
#  'TO',
#  'dETECTIVES',
#  'VIII',
#  'IN',
#  'WHICH',
#  'PASSEPARTOUT',
#  'TALKS',
#  'RATHER',
#  'MORE',
#  'PERHAPS',
#  'THAN',
#  'IS',
#  'PRUDENT',
#  'IX',
#  'IN',
#  'WHICH',
#  'THE',
#  'RED',
#  'SEA',
#  'AND',
#  'THE',
#  'INDIAN',
#  'OCEAN',
#  'PROVE',
#  'PROPITIOUS',
#  'TO',
#  'THE',
#  'DESIGNS',
#  'OF',
#  'PHILEAS',
#  'FOGG',
#  'X',
#  'IN',
#  'WHICH',
#  'PASSEPARTOUT',
#  'IS',
#  'ONLY',
#  'TOO',
#  'GLAD',
#  'TO',
#  'GET',
#  'OFF',
#  'WITH',
#  'THE',
#  'LOSS',
#  'OF',
#  'HIS',
#  'SHOES',
#  'XI',
#  'IN',
#  'WHICH',
#  'PHILEAS',
#  'FOGG',
#  'SECURES',
#  'A',
#  'CURIOUS',
#  'MEANS',
#  'OF',
#  'CONVEYANCE',
#  'AT',
#  'A',
#  'FABULOUS',
#  'PRICE',
#  'XII',
#  'IN',
#  'WHICH',
#  'PHILEAS',
#  'FOGG',
#  'AND',
#  'HIS',
#  'COMPANIONS',
#  'VENTURE',
#  'ACROSS',
#  'THE',
#  'INDIAN',
#  'FORESTS',
#  'AND',
#  'WHAT',
#  'ENSUED',
#  'XIII',
#  'IN',
#  'WHICH',
#  'PASSEPARTOUT',
#  'RECEIVES',
#  'A',
#  'NEW',
#  'PROOF',
#  'THAT',
#  'FORTUNE',
#  'FAVORS',
#  'THE',
#  'BRAVE',
#  'XIV',
#  'IN',
#  'WHICH',
#  'PHILEAS',
#  'FOGG',
#  'DESCENDS',
#  'THE',
#  'WHOLE',
#  'LENGTH',
#  'OF',
#  'THE',
#  'BEAUTIFUL',
#  'VALLEY',
#  'OF',
#  'THE',
#  'GANGES',
#  'WITHOUT',
#  'EVER',
#  'THINKING',
#  'OF',
#  'SEEING',
#  'IT',
#  'XV',
#  'IN',
#  'WHICH',
#  'THE',
#  'BAG',
#  'OF',
#  'BANKNOTES',
#  'DISGORGES',
#  'SOME',
#  'THOUSANDS',
#  'OF',
#  'POUNDS',
#  'MORE',
#  'XVI',
#  'IN',
#  'WHICH',
#  'FIX',
#  'DOES',
#  'NOT',
#  'SEEM',
#  'TO',
#  'UNDERSTAND',
#  'IN',
#  'THE',
#  'LEAST',
#  'WHAT',
#  'IS',
#  'SAID',
#  'TO',
#  'HIM',
#  'XVII',
#  'SHOWING',
#  'WHAT',
#  'HAPPENED',
#  'ON',
#  'THE',
#  'VOYAGE',
#  'FROM',
#  'SINGAPORE',
#  'TO',
#  'HONG',
#  'KONG',
#  'XVIII',
#  'IN',
#  'WHICH',
#  'PHILEAS',
#  'FOGG',
#  'PASSEPARTOUT',
#  'AND',
#  'FIX',
#  'GO',
#  'EACH',
#  'ABOUT',
#  'HIS',
#  'BUSINESS',
#  'XIX',
#  'IN',
#  'WHICH',
#  'PASSEPARTOUT',
#  'TAKES',
#  'A',
#  'TOO',
#  'GREAT',
#  'INTEREST',
#  'IN',
#  'HIS',
#  'MASTER',
#  'AND',
#  'WHAT',
#  'COMES',
#  'OF',
#  'IT',
#  'XX',
#  'IN',
#  'WHICH',
#  'FIX',
#  'COMES',
#  'FACE',
#  'TO',
#  'FACE',
#  'WITH',
#  'PHILEAS',
#  'FOGG',
#  'XXI',
#  'IN',
#  'WHICH',
#  'THE',
#  'MASTER',
#  'OF',
#  'THE',
#  'TANKADERE',
#  'RUNS',
#  'GREAT',
#  'RISK',
#  'OF',
#  'LOSING',
#  'A',
#  'REWARD',
#  'OF',
#  'TWO',
#  'HUNDRED',
#  'POUNDS',
#  'XXII',
#  'IN',
#  'WHICH',
#  'PASSEPARTOUT',
#  'FINDS',
#  'OUT',
#  'THAT',
#  'EVEN',
#  'AT',
#  'THE',
#  'ANTIPODES',
#  'IT',
#  'IS',
#  'CONVENIENT',
#  'TO',
#  'HAVE',
#  'SOME',
#  'MONEY',
#  'IN',
#  'ONES',
#  'POCKET',
#  'XXIII',
#  'IN',
#  'WHICH',
#  'PASSEPARTOUTS',
#  'NOSE',
#  'BECOMES',
#  'OUTRAGEOUSLY',
#  'LONG',
#  'XXIV',
#  'DURING',
#  'WHICH',
#  'MR',
#  'FOGG',
#  'AND',
#  'PARTY',
#  'CROSS',
#  'THE',
#  'PACIFIC',
#  'OCEAN',
#  'XXV',
#  'IN',
#  'WHICH',
#  'A',
#  'SLIGHT',
#  'GLIMPSE',
#  'IS',
#  'HAD',
#  'OF',
#  'SAN',
#  'FRANCISCO',
#  'XXVI',
#  'IN',
#  'WHICH',
#  'PHILEAS',
#  'FOGG',
#  'AND',
#  'PARTY',
#  'TRAVEL',
#  'BY',
#  'THE',
#  'PACIFIC',
#  'RAILROAD',
#  'XXVII',
#  'IN',
#  'WHICH',
#  'PASSEPARTOUT',
#  'UNDERGOES',
#  'AT',
#  'A',
#  'SPEED',
#  'OF',
#  'TWENTY',
#  'MILES',
#  'AN',
#  'HOUR',
#  'A',
#  'COURSE',
#  'OF',
#  'MORMON',
#  'HISTORY',
#  'XXVIII',
#  'IN',
#  'WHICH',
#  'PASSEPARTOUT',
#  'DOES',
#  'NOT',
#  'SUCCEED',
#  'IN',
#  'MAKING',
#  'ANYBODY',
#  'LISTEN',
#  'TO',
#  'REASON',
#  'XXIX',
#  'IN',
#  'WHICH',
#  'CERTAIN',
#  'INCIDENTS',
#  'ARE',
#  'NARRATED',
#  'WHICH',
#  'ARE',
#  'ONLY',
#  'TO',
#  'BE',
#  'MET',
#  'WITH',
#  'ON',
#  'AMERICAN',
#  'RAILROADS',
#  'XXX',
#  'IN',
#  'WHICH',
#  'PHILEAS',
#  'FOGG',
#  'SIMPLY',
#  'DOES',
#  'HIS',
#  'DUTY',
#  'XXXI',
#  'IN',
#  'WHICH',
#  'FIX',
#  'THE',
#  'DETECTIVE',
#  'CONSIDERABLY',
#  'FURTHERS',
#  'THE',
#  'INTERESTS',
#  'OF',
#  'PHILEAS',
#  'FOGG',
#  'XXXII',
#  'IN',
#  'WHICH',
#  'PHILEAS',
#  'FOGG',
#  'ENGAGES',
#  'IN',
#  'A',
#  'DIRECT',
#  'STRUGGLE',
#  'WITH',
#  'BAD',
#  'FORTUNE',
#  'XXXIII',
#  'IN',
#  'WHICH',
#  'PHILEAS',
#  'FOGG',
#  'SHOWS',
#  'HIMSELF',
#  'EQUAL',
#  'TO',
#  'THE',
#  'OCCASION',
#  'XXXIV',
#  'IN',
#  'WHICH',
#  'PHILEAS',
#  'FOGG',
#  'AT',
#  'LAST',
#  'REACHES',
#  'LONDON',
#  'XXXV',
#  'IN',
#  'WHICH',
#  'PHILEAS',
#  'FOGG',
#  'DOES',
#  'NOT',
#  'HAVE',
#  'TO',
#  'REPEAT',
#  'HIS',
#  'ORDERS',
#  'TO',
#  'PASSEPARTOUT',
#  'TWICE',
#  'XXXVI',
#  'IN',
#  'WHICH',
#  'PHILEAS',
#  'FOGGS',
#  'NAME',
#  'IS',
#  'ONCE',
#  'MORE',
#  'AT',
#  'A',
#  'PREMIUM',
#  'ON',
#  'CHANGE',
#  'XXXVII',
#  'IN',
#  'WHICH',
#  'IT',
#  'IS',
#  'SHOWN',
#  'THAT',
#  'PHILEAS',
#  'FOGG',
#  'GAINED',
#  'NOTHING',
#  'BY',
#  'HIS',
#  'TOUR',
#  'AROUND',
#  'THE',
#  'WORLD',
#  'UNLESS',
#  'IT',
#  'WERE',
#  'HAPPINESS',
#  'Chapter',
#  'I',
#  'IN',
#  'WHICH',
#  'PHILEAS',
#  'FOGG',
#  'AND',
#  'PASSEPARTOUT',
#  'ACCEPT',
#  'EACH',
#  'OTHER',
#  'THE',
#  'ONE',
#  'AS',
#  'MASTER',
#  'THE',
#  'OTHER',
#  'AS',
#  'MAN',
#  'Mr',
#  'Phileas',
#  'Fogg',
#  'lived',
#  'in',
#  '1872',
#  'at',
#  'No',
#  '7',
#  'Saville',
#  'Row',
#  'Burlington',
#  'Gardens',
#  'the',
#  'house',
#  'in',
#  'which',
#  'Sheridan',
#  'died',
#  'in',
#  '1814',
#  'He',
#  'was',
#  'one',
#  'of',
#  'the',
#  'most',
#  'noticeable',
#  'members',
#  'of',
#  'the',
#  'Reform',
#  'Club',
#  'though',
#  'he',
#  'seemed',
#  'always',
#  'to',
#  'avoid',
#  'attracting',
#  'attention',
#  'an',
#  'enigmatical',
#  'personage',
#  'about',
#  'whom',
#  'little',
#  'was',
#  'known',
#  'except',
#  'that',
#  'he',
#  'was',
#  'a',
#  'polished',
#  'man',
#  'of',
#  'the',
#  'world',
#  'People',
#  'said',
#  'that',
#  'he',
#  'resembled',
#  'Byronat',
#  'least',
#  'that',
#  'his',
#  'head',
#  'was',
#  'Byronic',
#  'but',
#  'he',
#  'was',
#  'a',
#  'bearded',
#  'tranquil',
#  'Byron',
#  'who',
#  'might',
#  'live',
#  'on',
#  'a',
#  'thousand',
#  'years',
#  'without',
#  'growing',
#  'old',
#  'Certainly',
#  'an',
#  'Englishman',
#  'it',
#  'was',
#  'more',
#  'doubtful',
#  'whether',
#  'Phileas',
#  'Fogg',
#  'was',
#  'a',
#  'Londoner',
#  'He',
#  'was',
#  'never',
#  'seen',
#  'on',
#  'Change',
#  'nor',
#  'at',
#  'the',
#  'Bank',
#  'nor',
#  'in',
#  'the',
#  'countingrooms',
#  'of',
#  'the',
#  'City',
#  'no',
#  'ships',
#  'ever',
#  'came',
#  'into',
#  'London',
#  'docks',
#  'of',
#  'which',
#  'he',
#  'was',
#  'the',
#  'owner',
#  'he',
#  'had',
#  'no',
#  'public',
#  'employment',
#  'he',
#  'had',
#  'never',
#  'been',
#  'entered',
#  'at',
#  'any',
#  'of',
#  'the',
#  'Inns',
#  'of',
#  'Court',
#  'either',
#  'at',
#  'the',
#  'Temple',
#  'or',
#  'Lincolns',
#  'Inn',
#  'or',
#  'Grays',
#  'Inn',
#  'nor',
#  'had',
#  'his',
#  'voice',
#  'ever',
#  'resounded',
#  'in',
#  'the',
#  'Court',
#  'of',
#  'Chancery',
#  'or',
#  'in',
#  'the',
#  'Exchequer',
#  'or',
#  'the',
#  'Queens',
#  'Bench',
#  'or',
#  'the',
#  'Ecclesiastical',
#  'Courts',
#  'He',
#  'certainly',
#  'was',
#  'not',
#  'a',
#  'manufacturer',
#  'nor',
#  'was',
#  'he',
#  'a',
#  'merchant',
#  'or',
#  'a',
#  'gentleman',
#  'farmer',
#  'His',
#  'name',
#  'was',
#  'strange',
#  'to',
#  'the',
#  'scientific',
#  'and',
#  'learned',
#  'societies',
#  'and',
#  'he',
#  'never',
#  'was',
#  'known',
#  'to',
#  'take',
#  'part',
#  'in',
#  'the',
#  'sage',
#  'deliberations',
#  'of',
#  'the',
#  'Royal',
#  'Institution',
#  'or',
#  'the',
#  'London',
#  'Institution',
#  'the',
#  'Artisans',
#  'Association',
#  'or',
#  'the',
#  'Institution',
#  'of',
#  'Arts',
#  'and',
#  'Sciences',
#  'He',
#  'belonged',
#  'in',
#  'fact',
#  'to',
#  'none',
#  'of',
#  'the',
#  'numerous',
#  'societies',
#  'which',
#  'swarm',
#  'in',
#  'the',
#  'English',
#  'capital',
#  'from',
#  'the',
#  'Harmonic',
#  'to',
#  'that',
#  'of',
#  'the',
#  'Entomologists',
#  'founded',
#  'mainly',
#  'for',
#  'the',
#  'purpose',
#  'of',
#  'abolishing',
#  'pernicious',
#  'insects',
#  'Phileas',
#  'Fogg',
#  'was',
#  'a',
#  'member',
#  'of',
#  'the',
#  'Reform',
#  'and',
#  'that',
#  'was',
#  'all',
#  'The',
#  'way',
#  'in',
#  'which',
#  'he',
#  'got',
#  'admission',
#  'to',
#  'this',
#  'exclusive',
#  'club',
#  'was',
#  'simple',
#  'enough',
#  'He',
#  'was',
#  'recommended',
#  'by',
#  'the',
#  'Barings',
#  'with',
#  'whom',
#  'he',
#  'had',
#  'an',
#  'open',
#  'credit',
#  'His',
#  'cheques',
#  'were',
#  'regularly',
#  'paid',
#  'at',
#  'sight',
#  'from',
#  'his',
#  'account',
#  'current',
#  'which',
#  'was',
#  'always',
#  'flush',
#  'Was',
#  'Phileas',
#  'Fogg',
#  'rich',
#  'Undoubtedly',
#  'But',
#  'those',
#  'who',
#  'knew',
#  'him',
#  'best',
#  'could',
#  'not',
#  'imagine',
#  'how',
#  'he',
#  'had',
#  'made',
#  'his',
#  'fortune',
#  'and',
#  'Mr',
#  'Fogg',
#  'was',
#  'the',
#  ...]

# %%
# Now lets remove the stop words
rectify_sentence = [word for word in no_punctuation.split() if word.lower() not in stopwords.words('english')]
rectify_sentence
# Out:
# ['Project',
#  'Gutenberg',
#  'EBook',
#  'Around',
#  'World',
#  '80',
#  'Days',
#  'Jules',
#  'Verne',
#  'eBook',
#  'use',
#  'anyone',
#  'anywhere',
#  'cost',
#  'almost',
#  'restrictions',
#  'whatsoever',
#  'may',
#  'copy',
#  'give',
#  'away',
#  'reuse',
#  'terms',
#  'Project',
#  'Gutenberg',
#  'License',
#  'included',
#  'eBook',
#  'online',
#  'wwwgutenbergnet',
#  'Title',
#  'Around',
#  'World',
#  '80',
#  'Days',
#  'Author',
#  'Jules',
#  'Verne',
#  'Release',
#  'Date',
#  'May',
#  '15',
#  '2008',
#  'EBook',
#  '103',
#  'Last',
#  'updated',
#  'February',
#  '18',
#  '2012',
#  'Last',
#  'updated',
#  'May',
#  '5',
#  '2012',
#  'Language',
#  'English',
#  'START',
#  'PROJECT',
#  'GUTENBERG',
#  'EBOOK',
#  'AROUND',
#  'WORLD',
#  '80',
#  'DAYS',
#  'AROUND',
#  'WORLD',
#  'EIGHTY',
#  'DAYS',
#  'CONTENTS',
#  'CHAPTER',
#  'PHILEAS',
#  'FOGG',
#  'PASSEPARTOUT',
#  'ACCEPT',
#  'ONE',
#  'MASTER',
#  'MAN',
#  'II',
#  'PASSEPARTOUT',
#  'CONVINCED',
#  'LAST',
#  'FOUND',
#  'IDEAL',
#  'III',
#  'CONVERSATION',
#  'TAKES',
#  'PLACE',
#  'SEEMS',
#  'LIKELY',
#  'COST',
#  'PHILEAS',
#  'FOGG',
#  'DEAR',
#  'IV',
#  'PHILEAS',
#  'FOGG',
#  'ASTOUNDS',
#  'PASSEPARTOUT',
#  'SERVANT',
#  'V',
#  'NEW',
#  'SPECIES',
#  'FUNDS',
#  'UNKNOWN',
#  'MONEYED',
#  'MEN',
#  'APPEARS',
#  'CHANGE',
#  'VI',
#  'FIX',
#  'DETECTIVE',
#  'BETRAYS',
#  'NATURAL',
#  'IMPATIENCE',
#  'VII',
#  'DEMONSTRATES',
#  'USELESSNESS',
#  'PASSPORTS',
#  'AIDS',
#  'dETECTIVES',
#  'VIII',
#  'PASSEPARTOUT',
#  'TALKS',
#  'RATHER',
#  'PERHAPS',
#  'PRUDENT',
#  'IX',
#  'RED',
#  'SEA',
#  'INDIAN',
#  'OCEAN',
#  'PROVE',
#  'PROPITIOUS',
#  'DESIGNS',
#  'PHILEAS',
#  'FOGG',
#  'X',
#  'PASSEPARTOUT',
#  'GLAD',
#  'GET',
#  'LOSS',
#  'SHOES',
#  'XI',
#  'PHILEAS',
#  'FOGG',
#  'SECURES',
#  'CURIOUS',
#  'MEANS',
#  'CONVEYANCE',
#  'FABULOUS',
#  'PRICE',
#  'XII',
#  'PHILEAS',
#  'FOGG',
#  'COMPANIONS',
#  'VENTURE',
#  'ACROSS',
#  'INDIAN',
#  'FORESTS',
#  'ENSUED',
#  'XIII',
#  'PASSEPARTOUT',
#  'RECEIVES',
#  'NEW',
#  'PROOF',
#  'FORTUNE',
#  'FAVORS',
#  'BRAVE',
#  'XIV',
#  'PHILEAS',
#  'FOGG',
#  'DESCENDS',
#  'WHOLE',
#  'LENGTH',
#  'BEAUTIFUL',
#  'VALLEY',
#  'GANGES',
#  'WITHOUT',
#  'EVER',
#  'THINKING',
#  'SEEING',
#  'XV',
#  'BAG',
#  'BANKNOTES',
#  'DISGORGES',
#  'THOUSANDS',
#  'POUNDS',
#  'XVI',
#  'FIX',
#  'SEEM',
#  'UNDERSTAND',
#  'LEAST',
#  'SAID',
#  'XVII',
#  'SHOWING',
#  'HAPPENED',
#  'VOYAGE',
#  'SINGAPORE',
#  'HONG',
#  'KONG',
#  'XVIII',
#  'PHILEAS',
#  'FOGG',
#  'PASSEPARTOUT',
#  'FIX',
#  'GO',
#  'BUSINESS',
#  'XIX',
#  'PASSEPARTOUT',
#  'TAKES',
#  'GREAT',
#  'INTEREST',
#  'MASTER',
#  'COMES',
#  'XX',
#  'FIX',
#  'COMES',
#  'FACE',
#  'FACE',
#  'PHILEAS',
#  'FOGG',
#  'XXI',
#  'MASTER',
#  'TANKADERE',
#  'RUNS',
#  'GREAT',
#  'RISK',
#  'LOSING',
#  'REWARD',
#  'TWO',
#  'HUNDRED',
#  'POUNDS',
#  'XXII',
#  'PASSEPARTOUT',
#  'FINDS',
#  'EVEN',
#  'ANTIPODES',
#  'CONVENIENT',
#  'MONEY',
#  'ONES',
#  'POCKET',
#  'XXIII',
#  'PASSEPARTOUTS',
#  'NOSE',
#  'BECOMES',
#  'OUTRAGEOUSLY',
#  'LONG',
#  'XXIV',
#  'MR',
#  'FOGG',
#  'PARTY',
#  'CROSS',
#  'PACIFIC',
#  'OCEAN',
#  'XXV',
#  'SLIGHT',
#  'GLIMPSE',
#  'SAN',
#  'FRANCISCO',
#  'XXVI',
#  'PHILEAS',
#  'FOGG',
#  'PARTY',
#  'TRAVEL',
#  'PACIFIC',
#  'RAILROAD',
#  'XXVII',
#  'PASSEPARTOUT',
#  'UNDERGOES',
#  'SPEED',
#  'TWENTY',
#  'MILES',
#  'HOUR',
#  'COURSE',
#  'MORMON',
#  'HISTORY',
#  'XXVIII',
#  'PASSEPARTOUT',
#  'SUCCEED',
#  'MAKING',
#  'ANYBODY',
#  'LISTEN',
#  'REASON',
#  'XXIX',
#  'CERTAIN',
#  'INCIDENTS',
#  'NARRATED',
#  'MET',
#  'AMERICAN',
#  'RAILROADS',
#  'XXX',
#  'PHILEAS',
#  'FOGG',
#  'SIMPLY',
#  'DUTY',
#  'XXXI',
#  'FIX',
#  'DETECTIVE',
#  'CONSIDERABLY',
#  'FURTHERS',
#  'INTERESTS',
#  'PHILEAS',
#  'FOGG',
#  'XXXII',
#  'PHILEAS',
#  'FOGG',
#  'ENGAGES',
#  'DIRECT',
#  'STRUGGLE',
#  'BAD',
#  'FORTUNE',
#  'XXXIII',
#  'PHILEAS',
#  'FOGG',
#  'SHOWS',
#  'EQUAL',
#  'OCCASION',
#  'XXXIV',
#  'PHILEAS',
#  'FOGG',
#  'LAST',
#  'REACHES',
#  'LONDON',
#  'XXXV',
#  'PHILEAS',
#  'FOGG',
#  'REPEAT',
#  'ORDERS',
#  'PASSEPARTOUT',
#  'TWICE',
#  'XXXVI',
#  'PHILEAS',
#  'FOGGS',
#  'NAME',
#  'PREMIUM',
#  'CHANGE',
#  'XXXVII',
#  'SHOWN',
#  'PHILEAS',
#  'FOGG',
#  'GAINED',
#  'NOTHING',
#  'TOUR',
#  'AROUND',
#  'WORLD',
#  'UNLESS',
#  'HAPPINESS',
#  'Chapter',
#  'PHILEAS',
#  'FOGG',
#  'PASSEPARTOUT',
#  'ACCEPT',
#  'ONE',
#  'MASTER',
#  'MAN',
#  'Mr',
#  'Phileas',
#  'Fogg',
#  'lived',
#  '1872',
#  '7',
#  'Saville',
#  'Row',
#  'Burlington',
#  'Gardens',
#  'house',
#  'Sheridan',
#  'died',
#  '1814',
#  'one',
#  'noticeable',
#  'members',
#  'Reform',
#  'Club',
#  'though',
#  'seemed',
#  'always',
#  'avoid',
#  'attracting',
#  'attention',
#  'enigmatical',
#  'personage',
#  'little',
#  'known',
#  'except',
#  'polished',
#  'man',
#  'world',
#  'People',
#  'said',
#  'resembled',
#  'Byronat',
#  'least',
#  'head',
#  'Byronic',
#  'bearded',
#  'tranquil',
#  'Byron',
#  'might',
#  'live',
#  'thousand',
#  'years',
#  'without',
#  'growing',
#  'old',
#  'Certainly',
#  'Englishman',
#  'doubtful',
#  'whether',
#  'Phileas',
#  'Fogg',
#  'Londoner',
#  'never',
#  'seen',
#  'Change',
#  'Bank',
#  'countingrooms',
#  'City',
#  'ships',
#  'ever',
#  'came',
#  'London',
#  'docks',
#  'owner',
#  'public',
#  'employment',
#  'never',
#  'entered',
#  'Inns',
#  'Court',
#  'either',
#  'Temple',
#  'Lincolns',
#  'Inn',
#  'Grays',
#  'Inn',
#  'voice',
#  'ever',
#  'resounded',
#  'Court',
#  'Chancery',
#  'Exchequer',
#  'Queens',
#  'Bench',
#  'Ecclesiastical',
#  'Courts',
#  'certainly',
#  'manufacturer',
#  'merchant',
#  'gentleman',
#  'farmer',
#  'name',
#  'strange',
#  'scientific',
#  'learned',
#  'societies',
#  'never',
#  'known',
#  'take',
#  'part',
#  'sage',
#  'deliberations',
#  'Royal',
#  'Institution',
#  'London',
#  'Institution',
#  'Artisans',
#  'Association',
#  'Institution',
#  'Arts',
#  'Sciences',
#  'belonged',
#  'fact',
#  'none',
#  'numerous',
#  'societies',
#  'swarm',
#  'English',
#  'capital',
#  'Harmonic',
#  'Entomologists',
#  'founded',
#  'mainly',
#  'purpose',
#  'abolishing',
#  'pernicious',
#  'insects',
#  'Phileas',
#  'Fogg',
#  'member',
#  'Reform',
#  'way',
#  'got',
#  'admission',
#  'exclusive',
#  'club',
#  'simple',
#  'enough',
#  'recommended',
#  'Barings',
#  'open',
#  'credit',
#  'cheques',
#  'regularly',
#  'paid',
#  'sight',
#  'account',
#  'current',
#  'always',
#  'flush',
#  'Phileas',
#  'Fogg',
#  'rich',
#  'Undoubtedly',
#  'knew',
#  'best',
#  'could',
#  'imagine',
#  'made',
#  'fortune',
#  'Mr',
#  'Fogg',
#  'last',
#  'person',
#  'apply',
#  'information',
#  'lavish',
#  'contrary',
#  'avaricious',
#  'whenever',
#  'knew',
#  'money',
#  'needed',
#  'noble',
#  'useful',
#  'benevolent',
#  'purpose',
#  'supplied',
#  'quietly',
#  'sometimes',
#  'anonymously',
#  'short',
#  'least',
#  'communicative',
#  'men',
#  'talked',
#  'little',
#  'seemed',
#  'mysterious',
#  'taciturn',
#  'manner',
#  'daily',
#  'habits',
#  'quite',
#  'open',
#  'observation',
#  'whatever',
#  'exactly',
#  'thing',
#  'always',
#  'done',
#  'wits',
#  'curious',
#  'fairly',
#  'puzzled',
#  'travelled',
#  'likely',
#  'one',
#  'seemed',
#  'know',
#  'world',
#  'familiarly',
#  'spot',
#  'secluded',
#  'appear',
#  'intimate',
#  'acquaintance',
#  'often',
#  'corrected',
#  'clear',
#  'words',
#  'thousand',
#  'conjectures',
#  'advanced',
#  'members',
#  'club',
#  'lost',
#  'unheardof',
#  'travellers',
#  'pointing',
#  'true',
#  'probabilities',
#  'seeming',
#  'gifted',
#  'sort',
#  'second',
#  'sight',
#  'often',
#  'events',
#  'justify',
#  'predictions',
#  'must',
#  'travelled',
#  'everywhere',
#  'least',
#  'spirit',
#  'least',
#  'certain',
#  'Phileas',
#  'Fogg',
#  'absented',
#  'London',
#  'many',
#  'years',
#  'honoured',
#  'better',
#  'acquaintance',
#  'rest',
#  'declared',
#  'nobody',
#  'could',
#  'pretend',
#  'ever',
#  'seen',
#  'anywhere',
#  'else',
#  'sole',
#  'pastimes',
#  'reading',
#  'papers',
#  'playing',
#  'whist',
#  'often',
#  'game',
#  'silent',
#  'one',
#  'harmonised',
#  'nature',
#  'winnings',
#  'never',
#  'went',
#  'purse',
#  'reserved',
#  'fund',
#  'charities',
#  'Mr',
#  'Fogg',
#  'played',
#  'win',
#  'sake',
#  'playing',
#  'game',
#  'eyes',
#  'contest',
#  'struggle',
#  'difficulty',
#  'yet',
#  'motionless',
#  'unwearying',
#  'struggle',
#  'congenial',
#  'tastes',
#  'Phileas',
#  'Fogg',
#  'known',
#  'either',
#  'wife',
#  'children',
#  'may',
#  'happen',
#  'honest',
#  'people',
#  'either',
#  'relatives',
#  'near',
#  'friends',
#  'certainly',
#  'unusual',
#  'lived',
#  'alone',
#  'house',
#  'Saville',
#  'Row',
#  'whither',
#  'none',
#  'penetrated',
#  'single',
#  'domestic',
#  'sufficed',
#  'serve',
#  'breakfasted',
#  'dined',
#  'club',
#  'hours',
#  'mathematically',
#  'fixed',
#  'room',
#  'table',
#  'never',
#  'taking',
#  'meals',
#  'members',
#  'much',
#  'less',
#  'bringing',
#  'guest',
#  'went',
#  'home',
#  'exactly',
#  'midnight',
#  'retire',
#  'bed',
#  'never',
#  'used',
#  'cosy',
#  'chambers',
#  'Reform',
#  'provides',
#  'favoured',
#  'members',
#  'passed',
#  'ten',
#  'hours',
#  'twentyfour',
#  'Saville',
#  'Row',
#  'either',
#  'sleeping',
#  'making',
#  'toilet',
#  'chose',
#  'take',
#  'walk',
#  'regular',
#  'step',
#  'entrance',
#  'hall',
#  'mosaic',
#  'flooring',
#  'circular',
#  'gallery',
#  'dome',
#  'supported',
#  'twenty',
#  'red',
#  'porphyry',
#  'Ionic',
#  'columns',
#  'illumined',
#  'blue',
#  'painted',
#  'windows',
#  'breakfasted',
#  'dined',
#  'resources',
#  'clubits',
#  'kitchens',
#  'pantries',
#  'buttery',
#  'dairyaided',
#  'crowd',
#  'table',
#  'succulent',
#  'stores',
#  'served',
#  'gravest',
#  'waiters',
#  'dress',
#  'coats',
#  'shoes',
#  'swanskin',
#  'soles',
#  'proffered',
#  'viands',
#  'special',
#  'porcelain',
#  'finest',
#  'linen',
#  'club',
#  'decanters',
#  'lost',
#  'mould',
#  'contained',
#  'sherry',
#  'port',
#  'cinnamonspiced',
#  'claret',
#  'beverages',
#  'refreshingly',
#  'cooled',
#  'ice',
#  'brought',
#  'great',
#  'cost',
#  'American',
#  'lakes',
#  'live',
#  'style',
#  'eccentric',
#  'must',
#  'confessed',
#  'something',
#  'good',
#  'eccentricity',
#  'mansion',
#  'Saville',
#  'Row',
#  'though',
#  'sumptuous',
#  'exceedingly',
#  'comfortable',
#  'habits',
#  'occupant',
#  'demand',
#  'little',
#  'sole',
#  'domestic',
#  'Phileas',
#  'Fogg',
#  'required',
#  'almost',
#  'superhumanly',
#  'prompt',
#  'regular',
#  '2nd',
#  'October',
#  'dismissed',
#  'James',
#  'Forster',
#  'luckless',
#  'youth',
#  'brought',
#  'shavingwater',
#  'eightyfour',
#  'degrees',
#  'Fahrenheit',
#  'instead',
#  'eightysix',
#  'awaiting',
#  'successor',
#  'due',
#  'house',
#  'eleven',
#  'halfpast',
#  'Phileas',
#  'Fogg',
#  'seated',
#  'squarely',
#  'armchair',
#  'feet',
#  'close',
#  'together',
#  'like',
#  'grenadier',
#  'parade',
#  'hands',
#  'resting',
#  'knees',
#  'body',
#  'straight',
#  'head',
#  'erect',
#  'steadily',
#  'watching',
#  'complicated',
#  'clock',
#  'indicated',
#  'hours',
#  'minutes',
#  'seconds',
#  'days',
#  'months',
#  'years',
#  'exactly',
#  'halfpast',
#  'eleven',
#  'Mr',
#  'Fogg',
#  'would',
#  'according',
#  'daily',
#  'habit',
#  'quit',
#  'Saville',
#  'Row',
#  'repair',
#  'Reform',
#  'rap',
#  'moment',
#  'sounded',
#  'door',
#  'cosy',
#  'apartment',
#  'Phileas',
#  'Fogg',
#  'seated',
#  'James',
#  'Forster',
#  'dismissed',
#  'servant',
#  'appeared',
#  'new',
#  'servant',
#  'said',
#  'young',
#  'man',
#  'thirty',
#  'advanced',
#  'bowed',
#  'Frenchman',
#  'believe',
#  'asked',
#  'Phileas',
#  'Fogg',
#  'name',
#  'John',
#  'Jean',
#  'monsieur',
#  'pleases',
#  'replied',
#  'newcomer',
#  'Jean',
#  'Passepartout',
#  'surname',
#  'clung',
#  'natural',
#  'aptness',
#  'going',
#  'one',
#  'business',
#  'another',
#  'believe',
#  'Im',
#  'honest',
#  'monsieur',
#  'outspoken',
#  'Ive',
#  'several',
#  'trades',
#  'Ive',
#  'itinerant',
#  'singer',
#  'circusrider',
#  'used',
#  'vault',
#  'like',
#  'Leotard',
#  'dance',
#  'rope',
#  'like',
#  'Blondin',
#  'got',
#  'professor',
#  'gymnastics',
#  'make',
#  'better',
#  'use',
#  'talents',
#  'sergeant',
#  'fireman',
#  'Paris',
#  'assisted',
#  'many',
#  'big',
#  'fire',
#  'quitted',
#  'France',
#  'five',
#  'years',
#  'ago',
#  'wishing',
#  'taste',
#  'sweets',
#  'domestic',
#  'life',
#  'took',
#  'service',
#  'valet',
#  'England',
#  'Finding',
#  'place',
#  'hearing',
#  'Monsieur',
#  'Phileas',
#  'Fogg',
#  'exact',
#  'settled',
#  'gentleman',
#  'United',
#  'Kingdom',
#  'come',
#  'monsieur',
#  'hope',
#  'living',
#  'tranquil',
#  'life',
#  'forgetting',
#  'even',
#  'name',
#  ...]

# %%
# Counts each word number of times it has featured in the book
counts = Counter(rectify_sentence)
print(counts)
# Out:
# Counter({'Fogg': 565, 'Mr': 387, 'Passepartout': 378, 'would': 270, 'Fix': 229, 'Phileas': 219, 'said': 191, 'one': 155, 'could': 136, 'time': 125, 'Aouda': 125, 'upon': 120, 'train': 119, 'master': 97, 'hundred': 96, 'replied': 93, 'two': 93, 'hours': 89, 'thousand': 88, 'made': 87, 'steamer': 86, 'Project': 83, 'day': 82, 'without': 82, 'like': 80, 'days': 79, 'going': 75, 'man': 73, 'left': 72, 'passed': 71, 'seemed': 70, 'miles': 68, 'found': 66, 'London': 66, 'must': 66, 'took': 66, 'pounds': 64, 'minutes': 64, 'English': 63, 'twenty': 63, 'Sir': 62, 'detective': 61, 'go': 61, 'Hong': 61, 'Kong': 60, 'Bombay': 59, 'last': 58, 'thought': 58, 'might': 58, 'asked': 57, 'great': 57, 'world': 56, 'returned': 56, 'still': 56, 'long': 56, 'Gutenbergtm': 55, 'way': 55, 'hour': 55, 'passengers': 54, 'three': 54, 'work': 53, 'Francis': 53, 'well': 52, 'little': 52, 'least': 52, 'oclock': 51, 'make': 50, 'first': 50, 'journey': 49, 'good': 49, 'know': 49, 'went': 48, 'wind': 47, 'five': 47, 'soon': 47, 'station': 46, 'moment': 46, 'came': 45, 'servant': 45, 'evening': 45, 'nothing': 45, 'take': 44, 'Yes': 44, 'hand': 43, 'cried': 43, 'nine': 42, 'Foggs': 42, 'young': 41, 'eyes': 41, 'eight': 41, 'place': 41, 'see': 40, 'much': 40, 'may': 40, 'Yokohama': 40, 'several': 40, 'sea': 39, 'next': 39, 'gentleman': 39, 'shall': 38, 'leave': 38, 'followed': 38, 'board': 38, 'even': 38, 'India': 38, 'however': 38, 'sir': 38, 'put': 37, 'Chapter': 37, 'reached': 37, 'ten': 37, 'PHILEAS': 36, 'set': 36, 'stopped': 36, 'guide': 36, 'FOGG': 36, 'Reform': 36, 'four': 35, 'full': 35, 'Well': 35, 'never': 35, 'Indian': 35, 'reach': 35, 'course': 34, 'large': 34, 'speed': 34, 'began': 34, 'back': 34, 'got': 34, 'head': 34, 'woman': 34, 'along': 33, 'car': 33, 'heard': 33, 'Calcutta': 33, 'get': 33, 'morning': 33, 'New': 33, 'though': 33, 'away': 32, 'night': 32, 'entered': 32, 'part': 32, 'works': 32, 'railway': 32, 'us': 31, 'lost': 31, 'became': 31, 'quarter': 30, 'saw': 30, 'really': 30, 'San': 30, 'travellers': 30, 'resumed': 30, 'Parsee': 30, 'find': 30, 'American': 30, 'six': 30, 'Mongolia': 29, 'boat': 29, 'less': 29, 'behind': 29, 'fellow': 29, 'necessary': 29, 'captain': 29, 'whose': 29, 'seen': 29, 'Carnatic': 29, 'every': 29, 'already': 29, 'England': 29, 'country': 28, 'Francisco': 28, 'Liverpool': 28, 'appeared': 28, 'Stuart': 28, 'yet': 28, 'Suez': 28, 'end': 28, 'feet': 28, 'engineer': 27, 'elephant': 27, 'say': 27, 'hope': 27, 'electronic': 27, 'twelve': 27, 'towards': 27, 'hands': 27, 'York': 27, 'watch': 27, 'gave': 27, 'robber': 27, 'far': 27, 'quite': 26, 'around': 26, 'certain': 26, 'delay': 26, 'face': 26, 'locomotive': 26, 'taken': 26, 'Gutenberg': 26, 'masters': 26, 'deck': 26, 'round': 26, 'crowd': 25, 'Indians': 25, 'alone': 25, 'door': 25, 'Club': 25, 'remained': 25, 'ready': 25, 'within': 25, 'ever': 25, 'many': 25, 'wager': 25, 'come': 25, 'leaving': 25, 'halfpast': 24, 'Henrietta': 24, 'PASSEPARTOUT': 24, 'streets': 24, 'since': 24, 'Omaha': 24, 'point': 24, 'departure': 24, 'half': 24, 'midst': 23, 'Proctor': 23, 'John': 23, 'sails': 23, 'let': 23, 'air': 23, 'means': 23, 'warrant': 23, 'seven': 23, 'think': 23, 'among': 23, 'town': 23, 'pagoda': 23, 'Japanese': 23, 'pilot': 23, 'rose': 23, 'eighty': 23, 'looked': 23, 'right': 22, 'old': 22, 'always': 22, 'steam': 22, 'held': 22, 'Ah': 22, 'room': 22, 'added': 22, 'Foundation': 21, 'possible': 21, 'steps': 21, 'also': 21, 'steamers': 21, 'eleven': 21, 'kept': 21, 'consul': 21, 'gentlemen': 21, 'stop': 21, 'tour': 21, 'done': 21, 'forward': 21, 'December': 21, 'Rangoon': 21, 'Colonel': 21, 'perhaps': 21, 'passport': 20, 'men': 20, 'years': 20, 'gone': 20, 'sent': 20, 'doubt': 20, 'arrest': 20, 'terms': 20, 'received': 20, 'heart': 20, 'sledge': 20, 'route': 20, 'party': 20, 'lose': 20, 'fell': 20, 'road': 20, 'idea': 20, 'dont': 20, 'passing': 20, 'Tankadere': 20, 'conductor': 20, 'thus': 20, 'life': 19, 'honour': 19, 'open': 19, 'trains': 19, 'noon': 19, 'another': 19,  ...
